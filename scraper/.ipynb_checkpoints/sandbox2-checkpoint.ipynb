# %%
from craigslist import CraigslistHousing
from dateutil.parser import parse
import time
import settings


def scrape():
    """
    Scrapes craigslist for a certain geographic area, and finds the latest listings.
    :param area:
    :return: A list of results.
    """
    # How many of these to scrape at once.
    MAX_LISTINGS = 5
    
    sub_city_area = settings.sub_city_area
    
#     filters = {'max_price': settings.MAX_PRICE, "min_price": settings.MIN_PRICE}
    filters = {'query':settings.query,
                 'search_titles':settings.search_titles,
                 'has_image':settings.has_image,
                 'posted_today':settings.posted_today,
                 'bundle_duplicates':settings.bundle_duplicates,
                 'private_room':settings.private_room,
                 'private_bath':settings.private_bath,
                 'cats_ok':settings.cats_ok,
                 'dogs_ok':settings.dogs_ok,
                 'min_price':settings.min_price,
                 'max_price':settings.max_price,
                 'min_ft2':settings.min_ft2,
                 'max_ft2':settings.max_ft2,
                 'min_bedrooms':settings.min_bedrooms,
                 'max_bedrooms':settings.max_bedrooms,
                 'min_bathrooms':settings.min_bathrooms,
                 'max_bathrooms':settings.max_bathrooms,
                 'no_smoking':settings.no_smoking,
                 'is_furnished':settings.is_furnished,
                 'wheelchair_acccess':settings.wheelchair_acccess,
                 'housing_type':settings.housing_type,
                 'laundry':settings.laundry,
                 'parking':settings.parking,
                 }
    
    
    cl_h = CraigslistHousing(site=settings.cl_site, 
                             category='apa',
                             area='sfc'
                             filters=filters)

    results = []
    gen = cl_h.get_results(sort_by='newest', 
                           geotagged=True, 
                           limit=MAX_LISTINGS,
                           include_details=True)
    
    while True:
        
        try:
            result = next(gen)
        except StopIteration:
            break
        except Exception:
            continue
        

        # Try parsing the price.
        price = 0
        try:
            price = float(result["price"].replace("$", ""))
        except Exception:
            pass

        results.append(result)

    return results

# %%
listings2 = scrape()

# %%
listings
# Out:
# [{'id': '6785956595',
#   'repost_of': None,
#   'name': 'Walk To Bart! Beautiful Renovated Beauty Now Available!',
#   'url': 'https://sfbay.craigslist.org/eby/apa/d/union-city-walk-to-bart-beautiful/6785956595.html',
#   'datetime': '2019-01-03 09:27',
#   'price': '$1961',
#   'where': 'fremont / union city / newark',
#   'has_image': True,
#   'has_map': True,
#   'geotag': (37.589434, -122.020972),
#   'bedrooms': None,
#   'area': '410ft2',
#   'body': "Call Us Today   show contact info\n\n\nCome and See our wonderful studio. This home has 410 sq ft of living space, comes with major appliances in the kitchen, lots of storage closet, and in a gated community. It is here waiting for you!\n\nParkside Apartments in Union City, CA is located within a lushly landscaped, gated community located within walking distance from Union City BART and Kennedy Park. Parkside Apartments is conveniently located near the 880/680 freeways and minutes from shopping at the Fremont Hub Shopping Center. Our spacious apartments feature walk-in closets, a fully-equipped kitchen with stainless steel appliances and a patio or balcony. Stay active in our 24-hr fitness center; relax by our pool or mingle at the barbeque and picnic area. Best of all, you'll be able to breathe easy because we are smoke-free living at Parkside apartments in Union City!\n\nOffice Hours\nMonday: 09:00 AM   - 06:00 PM  \nTuesday: 09:00 AM   - 06:00 PM  \nWednesday: 10:00 AM   - 06:00 PM  \nThursday: 09:00 AM   - 06:00 PM  \nFriday: 09:00 AM   - 06:00 PM  \nSaturday: 10:00 AM   - 05:00 PM  \nSunday: 10:00 AM   - 05:00 PM  \n\nParkside Apartments\n1501 Decoto Road",
#   'images': ['https://images.craigslist.org/00p0p_4zZN4RIItEQ_600x450.jpg',
#    'https://images.craigslist.org/00y0y_a13iTvv6ML8_600x450.jpg',
#    'https://images.craigslist.org/00b0b_9FWneeQcU5H_600x450.jpg',
#    'https://images.craigslist.org/00D0D_1YlJpzcdlmW_600x450.jpg',
#    'https://images.craigslist.org/00202_iskPGoVhg2u_600x450.jpg',
#    'https://images.craigslist.org/00I0I_7xxLwBCCrjW_600x450.jpg',
#    'https://images.craigslist.org/00J0J_fNOKuo4sAhc_600x450.jpg',
#    'https://images.craigslist.org/00E0E_bit3kuxKrp0_600x450.jpg',
#    'https://images.craigslist.org/00e0e_7CaWAMR1P4a_600x450.jpg']},
#  {'id': '6785953512',
#   'repost_of': None,
#   'name': 'Grand Avenue - Grand Apartment - You need to see this Fabulous 2br Uni',
#   'url': 'https://sfbay.craigslist.org/eby/apa/d/oakland-grand-avenue-grand-apartment/6785953512.html',
#   'datetime': '2019-01-03 09:25',
#   'price': '$2888',
#   'where': 'oakland lake merritt / grand',
#   'has_image': True,
#   'has_map': True,
#   'geotag': (37.809389, -122.255157),
#   'bedrooms': '2',
#   'area': None,
#   'body': "383 Grand Ave #2, Oakland\n 2 Bedroom/1 Bath remodel located in a architectural rich circa 1900s building located at the bustling border of where Grand Lake meets Adam's Point. Fully remodeled this unit boasts eloquence and crafted trends features original wood windows filling the room with natural light, brand new kitchen with black quartz counter and stainless steel appliances, recessed lighting throughout, stunning hardwood floors, and a full apartment remodel. \n\n The property is only minutes from the major East Bay arteries including: 580, 880, 24, and the Bay Bridge.   The property's close proximity to Lake Merritt provides residents access to recreational facilities that include a boating center, rowing club, Nature Science Center, playground, and a 3.5-mile jogging/bicycling path. \nProperty Description:  \n 1st Floor   \nParking available\nGranite countertop\nNatural light \n Stainless appliances \n Shared laundry\n Near by freeway access \nRent Information: \n Rent:  $2,888.00 monthly \n Deposit:  $2,988.00\n Owner pays water and garbage, tenant responsible for PG& E.\nCats &dogs considered at additional deposit.  \nMove In funds to be in Cashier's Check. \nRental Application requires Proof of Income and Current Credit Check \n Contact to view  \n  Please text or call for a viewing and any additional information.  \n\nShirley Fonseca \n\n\n\nJeanne Robertson\n\n - text or call\n\n\n\nmmg209\nBRE#990193",
#   'images': ['https://images.craigslist.org/00n0n_aCTXDP6Mscm_600x450.jpg',
#    'https://images.craigslist.org/00606_8Qn2Ti2iXCY_600x450.jpg',
#    'https://images.craigslist.org/00909_1USoXeDQb8i_600x450.jpg',
#    'https://images.craigslist.org/00I0I_eYgCJ7qIkUx_600x450.jpg',
#    'https://images.craigslist.org/00000_ikQQYOPuZ0m_600x450.jpg',
#    'https://images.craigslist.org/00202_6gxY9gniUu_600x450.jpg',
#    'https://images.craigslist.org/00m0m_1mvYww18iyp_600x450.jpg']},
#  {'id': '6785913208',
#   'repost_of': None,
#   'name': 'Advent- Spacious Ivy Hil Drive Apartment Available Now!',
#   'url': 'https://sfbay.craigslist.org/eby/apa/d/oakland-advent-spacious-ivy-hil-drive/6785913208.html',
#   'datetime': '2019-01-03 08:48',
#   'price': '$2595',
#   'where': 'oakland lake merritt / grand',
#   'has_image': True,
#   'has_map': True,
#   'geotag': (37.801163, -122.245291),
#   'bedrooms': '2',
#   'area': '800ft2',
#   'body': 'Advent- Spacious Ivy Hil Drive Apartment Available Now! \n\n\n\n\nProperty Address\n\n2209 Ivy Drive | Oakland, CA 94606\n\n\n  Available: 01/05/2019\n\n\n\nOffered By\n\nAdvent Properties, Inc. |  \n\n\n\n\nDescription\n\n    Important: Please do not apply to rent "sight unseen." We will not process rental applications until applicants have viewed the property.\n\n\nModern two bedroom apartment home with dining room and individual garage is now available! \n\nThis gorgeous well-maintained 4Plex comes finished with many modern updates, adding a touch of class to your living experience. Oversized living room with a large wall length picture window, double pane windows and plush carpet. \n\nNew warm neutral paint throughout, modern kitchen including stainless steel appliances, ice-maker, gas stove with vent hood,  tile floor, engineered designer stone counter tops and lots of cabinet space. \n\nBoth bedrooms has plush carpet. Last but surely not least, a  renovated, custom tiled bath, with tub and shower combo! \n\nThis is truly a must see and will not be on the market long! \n\nUtilities Responsible For: PG&E/Water/CABLE and INTERNET services.\n\nOwner pays for trash and landscaping services.\n\nArea: San Antonio is a large district in Oakland, California, encompassing the land east of Lake Merritt to Sausal Creek. It is one of the most diverse areas of the city. Close to public transportation and easy access to the 580 Freeway entrance. Close to Lake Merritt, grocery stores, shopping, restaurants and the Lakeshore District. The district is made up of a number of smaller neighborhoods, each with its own distinct personality, history. Welcome Home!\n\nMinimum credit score of 650 required.\n\nMinimum monthly income requirement 2.2x the monthly rent net (after taxes.)\n\nRenter\'s Insurance is required with Advent Properties listed as "additional interest."\n\n*Renters Insurance does not include earthquake damage.*\n\nPets Not considered. Restrictions apply. \n\nSection 8 is NOT considered for this property.\n\nThis is a smoke free building\n\n*** Upon approval of the application, applicant(s) will have 48 hours to obtain utilities in their name(s) and renters insurance PRIOR to receiving the lease agreement.\n\n*** Move in date must be 30 days or less from date of application approval.***\n\n* As property owner or manager we do not discriminate in the rental of property on the basis of race, color, religion, sex, sexual orientation, disability, familial status, or national origin.\n\n** Advent Properties, Inc. trusts that all material in flyer to be correct and assume no legal responsibility for the accuracy. All information is subject to change or withdrawal without further notice.\n\nCal BRE#01897998\n  \nAmenities\n\nstone counter-tops\nModern Appliances\nPlush Carpet\nTop Floor Residence\n4 Plex\nGarage Parking\nShared Coin-op Laundry\nDouble Pane Windows\nCeiling Fan\nNewly Painted\nTiled Kitchen\nClose to Public Transit\nClose Distance to Shops.\nClose to Freeways\nIvy Hill Neighborhood\n\nDetails\n\nBeds/Baths: 2BD/1.0BA\nSquare Feet: 800\n\nRental Terms\n\nRent: $2,595.00 \n\n    Available: 01/05/2019\n    Application Fee: $40.00\n    Security Deposit: $2,595.00\n\n  \nPet Policy\n\nCats not allowed\nDogs not allowed',
#   'images': ['https://images.craigslist.org/00y0y_1c3NlUqtRVd_600x450.jpg',
#    'https://images.craigslist.org/00Z0Z_6mVMazgLgrQ_600x450.jpg',
#    'https://images.craigslist.org/00L0L_3baJ5ocjEJf_600x450.jpg',
#    'https://images.craigslist.org/00M0M_3fReArRpvK5_600x450.jpg',
#    'https://images.craigslist.org/00V0V_ky5NSKhY2hu_600x450.jpg',
#    'https://images.craigslist.org/00404_2V8hCDWxvY2_600x450.jpg',
#    'https://images.craigslist.org/00m0m_j4O49EeV2en_600x450.jpg']},
#  {'id': '6785691908',
#   'repost_of': None,
#   'name': '$1500 / 300sf Private Studio South Berkeley',
#   'url': 'https://sfbay.craigslist.org/eby/apa/d/emeryvillesf-private-studio-south/6785691908.html',
#   'datetime': '2019-01-02 22:49',
#   'price': '$1500',
#   'where': 'berkeley',
#   'has_image': True,
#   'has_map': True,
#   'geotag': (37.84734, -122.281344),
#   'bedrooms': '1',
#   'area': '300ft2',
#   'body': '300 sf studio attached to a multi-unit house; available January 23, 2019 \n\nConveniently located in South Berkeley between Ashby BART station and San Pablo Ave. Enjoy restaurants, cafes, microbreweries, parks and other amenities -- all within walking distance!\n\nFeatures include:\n• private entrance \n• new flooring\n• free street parking \n• utilities included (includes garbage, water, gas, and electricity)\n• high-speed WiFi at an additional low shared cost\n• shared laundry on-site\n• quiet location \n• Near Berkeley Bowl West and Emeryville Trader Joes\n• Bus lines: F or 6 to UC Berkeley campus\n\nOther Information:\n• Monthly Rent: $1,500 \n• Security Deposit: $1,500 refundable\n• Application with references and credit check\n• 12 month lease preferred\n• No smoking\n• No pets\n\n\nPlease send an email with a little information about your self and a rental resume or summary of rental history.',
#   'images': ['https://images.craigslist.org/00A0A_ATdb4erm5D_600x450.jpg',
#    'https://images.craigslist.org/00g0g_3gSzMoYCfXm_600x450.jpg',
#    'https://images.craigslist.org/00N0N_dYreIfEbyzi_600x450.jpg']},
#  {'id': '6785654353',
#   'repost_of': None,
#   'name': 'Spacious Master Bedroom/Converted Living Room in Charming Neighborhood',
#   'url': 'https://sfbay.craigslist.org/sfc/apa/d/san-francisco-spacious-master-bedroom/6785654353.html',
#   'datetime': '2019-01-02 20:25',
#   'price': '$1625',
#   'where': 'lower pac hts',
#   'has_image': True,
#   'has_map': True,
#   'geotag': (37.787299, -122.433516),
#   'bedrooms': '2',
#   'area': None,
#   'body': "Looking for 1-2 new roommates in the Bay Area to enter a 6-month apartment lease (starting Feb 1 or earlier)! Seeking to rent out a master bedroom and converted living room.\n\nCharming neighborhood on Fillmore St. in Lower Pacific Heights with lots of cute restaurants nearby, 15 minutes to SOMA and close to public transportation. The apartment is incredibly spacious and full of natural light.\n\nYou'd be living with a product manager at Twitter. Please message me or email me at  \n for more information / viewings!\n\nMaster bedroom: $1625 / month\nConverted living room: $1225 / month\n*Standalone master bedroom: $2,200 / month\n\n*In the event that only the bedroom is rented - the living room is great for hosting social events",
#   'images': ['https://images.craigslist.org/00t0t_boyl4rvWcq8_600x450.jpg',
#    'https://images.craigslist.org/00202_8PJDFrC8p14_600x450.jpg',
#    'https://images.craigslist.org/00I0I_etGK1m7aolO_600x450.jpg',
#    'https://images.craigslist.org/00101_lE9W79LWtKo_600x450.jpg']}]

# %%
query = None # string
search_titles = True # Query searches titles only
has_image = True 
posted_today = True
bundle_duplicates = True
private_room = True
private_bath = True
cats_ok = False
dogs_ok = False
min_price = 0
max_price = 10000
min_ft2 = 0
max_ft2 = 10000
min_bedrooms = 0
max_bedrooms = 10
min_bathrooms = 0
max_bathrooms = 10
no_smoking = True
is_furnished = False
wheelchair_acccess = False
# Checklist: ['apartment', 'condo', 'cottage/cabin', 'duplex', 'flat', 'house', 'in-law', 'loft', 'townhouse', 'manufactured', 'assisted living', 'land']
housing_type = None
# Checklist: ['w/d in unit', 'w/d hookups', 'laundry in bldg', 'laundry on site', 'no laundry on site']
laundry = None
# Checklist: ['carport', 'attached garage', 'detached garage', 'off-street parking', 'street parking', 'valet parking', 'no parking']
parking = None
