# %%
from craigslist import CraigslistHousing
from dateutil.parser import parse
import time
import settings


def scrape():
    """
    Scrapes craigslist for a certain geographic area, and finds the latest listings.
    :param area:
    :return: A list of results.
    """
    cl_h = CraigslistHousing(site=settings.CRAIGSLIST_SITE, category=settings.CRAIGSLIST_HOUSING_SECTION,
                             filters={'max_price': settings.MAX_PRICE, "min_price": settings.MIN_PRICE})

    results = []
    gen = cl_h.get_results(sort_by='newest', 
                           geotagged=True, 
                           limit=settings.MAX_LISTINGS,
                           include_details=True)
    
    while True:
        
        try:
            result = next(gen)
        except StopIteration:
            break
        except Exception:
            continue
        

        # Try parsing the price.
        price = 0
        try:
            price = float(result["price"].replace("$", ""))
        except Exception:
            pass

        results.append(result)

    return results

# %%
listings = scrape()

# %%
listings
# Out:
# [{'id': '6778775435',
#   'repost_of': None,
#   'name': 'Bright, Tranquil Studio for Rent',
#   'url': 'https://sfbay.craigslist.org/eby/apa/d/oakland-bright-tranquil-studio-for-rent/6778775435.html',
#   'datetime': '2019-01-02 19:33',
#   'price': '$1700',
#   'where': 'oakland hills / mills',
#   'has_image': True,
#   'has_map': True,
#   'geotag': (37.7641, -122.1633),
#   'bedrooms': None,
#   'area': '500ft2',
#   'body': 'Studio for rent in the Millsmont Area.\n\nAmenities:\nPrivate entrance.\nWasher and Dryer inside studio.\nGated area.\nParking inside property.\nUtilities included, except cable and internet.\nBeautiful garden and large backyard to relax, read or meditate.\nAdditional limited garage storage available.\nWell established and very quiet neighborhood.\nThree minutes away access to 580 and Highway 13. Perfect for commuters to SFO, Emeryville or Berkeley or opposite direction.\n\n750.00 Security Deposit \n\nNo smoking or drugs.\nNo pets.\n\nStudio will be available for move in on January 1, 2019. If interested, please email me at lili0159yahoo.com to schedule a visit and complete an application. Applicants credit will be checked.',
#   'images': ['https://images.craigslist.org/00m0m_cixQJIxlAWK_600x450.jpg',
#    'https://images.craigslist.org/00r0r_9Edsgs67170_600x450.jpg',
#    'https://images.craigslist.org/00m0m_lAp54W0AFfM_600x450.jpg',
#    'https://images.craigslist.org/00V0V_d77eWPJgu4c_600x450.jpg',
#    'https://images.craigslist.org/00s0s_2aNVSjDx4Lp_600x450.jpg',
#    'https://images.craigslist.org/00z0z_dJsXZxpODQ2_600x450.jpg',
#    'https://images.craigslist.org/00w0w_l4hVn41Hl24_600x450.jpg',
#    'https://images.craigslist.org/00Z0Z_ldci4kA1a4_600x450.jpg',
#    'https://images.craigslist.org/00w0w_eX6X0lblsbm_600x450.jpg']},
#  {'id': '6785633725',
#   'repost_of': None,
#   'name': '"FULLY REMODELED" 1 Bdrm, 1 Bath, Apartment',
#   'url': 'https://sfbay.craigslist.org/eby/apa/d/oakland-fully-remodeled-1-bdrm-1-bath/6785633725.html',
#   'datetime': '2019-01-02 19:33',
#   'price': '$1695',
#   'where': 'West Oakland',
#   'has_image': True,
#   'has_map': True,
#   'geotag': (37.815971, -122.275581),
#   'bedrooms': '1',
#   'area': None,
#   'body': '2505 San Pablo Avenue #205\n\nRooms: 1 bedroom / 1 bath\nType: Apartment\nAvailability: Now\nCity/Neighborhood: West Oakland, close to North Berkeley BART Station\nShowing: By Appointment Only\nUtilities:  Paid by tenant (not included in rent amount)\nFeatures: \nThis unit is laid with hardwood floors while the kitchen comes equipped with a stainless steel stove, microwave, refrigerator, and laundry machines. \n\nTo view more properties please visit smcrents.com and click on available and upcoming tab\n\nNo Sec 8\n\nPlease contact Leasing Dept @  \n (call only) or  \n (call/text)\nOR email to  \n to get prompt response',
#   'images': ['https://images.craigslist.org/00U0U_dOcDGWE69wv_600x450.jpg',
#    'https://images.craigslist.org/01111_iyapOi8bmVj_600x450.jpg',
#    'https://images.craigslist.org/00z0z_agtIbZqNPEj_600x450.jpg',
#    'https://images.craigslist.org/00n0n_ivdyaD3mytZ_600x450.jpg',
#    'https://images.craigslist.org/00y0y_lWHbm1TlQZy_600x450.jpg',
#    'https://images.craigslist.org/00505_k5gGO0ebDEu_600x450.jpg',
#    'https://images.craigslist.org/00909_ayptGf6hMh1_600x450.jpg',
#    'https://images.craigslist.org/00G0G_7iz3ySpnunI_600x450.jpg',
#    'https://images.craigslist.org/00p0p_eeQUB9e5lla_600x450.jpg',
#    'https://images.craigslist.org/00m0m_5uR3Axo4OBo_600x450.jpg',
#    'https://images.craigslist.org/01111_j0za1pHd4To_600x450.jpg']},
#  {'id': '6785633330',
#   'repost_of': '6687772438',
#   'name': "1950's Private Vintage Studio Cottage In Historic Downtown -",
#   'url': 'https://sfbay.craigslist.org/sby/apa/d/santa-clara-1950s-private-vintage/6785633330.html',
#   'datetime': '2019-01-02 19:32',
#   'price': '$1850',
#   'where': 'santa clara',
#   'has_image': True,
#   'has_map': True,
#   'geotag': (37.3492, -121.953),
#   'bedrooms': '1',
#   'area': '542ft2',
#   'body': "This 1950's style updated studio cottage (living room-bedroom room combined) was originally built for occupancy for one person due to its relatively small kitchen and bathroom: since 1950, it has only been rented to one adult at a time.\n\nAttached 6' x 22' laundry/storage room which includes a washer/dryer in place.\n\nUtilities are minimal and are pro-rated with the tenants living in the front main house.\n\nThere is a new gas oven and range, new wall/wall carpet, and new kitchen countertops; microwave oven. There is a new 8000 BTU temp-controlled wall AC unit, tile floor in entry, kitchen, bath; large walk-in lighted closet with mirror sliding doors; electric heating. Fiberglass stall shower only (no bathtub). \n\nNo pets. No smoking.\n\nGeneral Terms: A 1-year lease is preferred. 1st Month Rent + $1850 Security Deposit Prior To Move In. Tenant to obtain a renter's insurance policy. Retired owner lives out-of-town and must pre-qualify any tenant prior to setting up appointment.  \n\nPrior to setting up an appointment to view the studio cottage, please provide answers to following questions.  \n\na) What is your estimated annual gross income?\nb) What is your most recent credit score?\n\nThank you very much for your interest.",
#    'https://images.craigslist.org/00j0j_9aDjD2pQHa2_600x450.jpg',
#    'https://images.craigslist.org/00U0U_7C9lvSzMQOF_600x450.jpg',
#    'https://images.craigslist.org/00o0o_elcFhgWbDc7_600x450.jpg',
#    'https://images.craigslist.org/00404_417sUgnLPgL_600x450.jpg',
#    'https://images.craigslist.org/00x0x_3GjjMwjU8V4_600x450.jpg',
#    'https://images.craigslist.org/00P0P_7KROgiUlrBE_600x450.jpg',
#    'https://images.craigslist.org/00Z0Z_drLcLanL1PR_600x450.jpg']},
#  {'id': '6785631301',
#   'repost_of': '3886624051',
#   'name': "*Studio Apartment in an 1880's Victorian... Great Neighborhood...",
#   'url': 'https://sfbay.craigslist.org/eby/apa/d/alameda-studio-apartment-in-an-1880s/6785631301.html',
#   'datetime': '2019-01-02 19:27',
#   'price': '$1595',
#   'where': 'alameda',
#   'has_image': True,
#   'has_map': True,
#   'geotag': (37.771228, -122.262511),
#   'bedrooms': None,
#   'area': '200ft2',
#   'body': "*Studio Apartment in an 1880's Victorian... Great Neighborhood...* \n\nAvailable Now \n\nCentral Location... Not far from Park St. and Crown Beach \nEasy commute to Downtown Oakland, Berkeley, and San Francisco \n\nThis is a non-smoking (of any kind), no dogs (of any kind), property \n\nMove-in: first month rent, security deposit; \nand a good credit score... 700+ \n\nAddress: 1423 Central Ave.  Apt. H\nAlameda, CA 94501\n\nRestaurants, and shopping are nearby on Park St.; \nTrader Joe's is close too, at SouthShore Shopping Center... \nPublic Transit available: \nAC Transit Bus Line and Golden Gate Ferry Service \n\nThe Room: $1595.00 per month\nApprox: 200 sq/ft\nSecond floor location... \nwindows facing east and the hills;\nlovely carpeted room,\na small kitchen with sink, counter, cabinets;\na small gas range, and refrigerator;\nthe apartment has a half bathroom with a toilet and sink; \njust outside the room there is a shared full bathroom,\nw/shower over tub...\nWater, garbage, and electricity is included in the rent;\ntenant pays for any other services\n\nLaundry on-site... common area includes yard and garden\n\nAvailable Now... if this posting is still up, the studio is still available.",
#   'images': ['https://images.craigslist.org/01515_5zWBciEKbkr_600x450.jpg',
#    'https://images.craigslist.org/00M0M_3dGTAlezBEX_600x450.jpg',
#    'https://images.craigslist.org/00l0l_gLWsxYmhzAZ_600x450.jpg',
#    'https://images.craigslist.org/00H0H_15KRJ0q1voG_600x450.jpg',
#    'https://images.craigslist.org/00A0A_5rMGVsGpNhQ_600x450.jpg',
#    'https://images.craigslist.org/00P0P_ik6fjMOfb5o_600x450.jpg',
#    'https://images.craigslist.org/00303_dmoyjcusX9W_600x450.jpg',
#    'https://images.craigslist.org/00g0g_icO4mmT14Aq_600x450.jpg',
#    'https://images.craigslist.org/00m0m_7cX1d579ePu_600x450.jpg']}]
