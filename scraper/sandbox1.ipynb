# %%
CraigslistHousing.show_filters()
# Out:
# Base filters:
# * query = ...
# * search_titles = True/False
# * has_image = True/False
# * posted_today = True/False
# * bundle_duplicates = True/False
# * search_distance = ...
# * zip_code = ...
# Section specific filters:
# * private_room = True/False
# * private_bath = True/False
# * cats_ok = True/False
# * dogs_ok = True/False
# * min_price = ...
# * max_price = ...
# * min_ft2 = ...
# * max_ft2 = ...
# * min_bedrooms = ...
# * max_bedrooms = ...
# * min_bathrooms = ...
# * max_bathrooms = ...
# * no_smoking = True/False
# * is_furnished = True/False
# * wheelchair_acccess = True/False
# * housing_type = 'apartment', 'condo', 'cottage/cabin', 'duplex', 'flat', 'house', 'in-law', 'loft', 'townhouse', 'manufactured', 'assisted living', 'land'
# * laundry = 'w/d in unit', 'w/d hookups', 'laundry in bldg', 'laundry on site', 'no laundry on site'
# * parking = 'carport', 'attached garage', 'detached garage', 'off-street parking', 'street parking', 'valet parking', 'no parking'

# %%
from craigslist import CraigslistBase
help(CraigslistBase)
# Out:
# Help on class CraigslistBase in module craigslist:
#
# class CraigslistBase(builtins.object)
#  |  CraigslistBase(site=None, area=None, category=None, filters=None, log_level=30)
#  |
#  |  Base class for all Craiglist wrappers.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, site=None, area=None, category=None, filters=None, log_level=30)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  customize_result(self, result, html_row)
#  |      Add custom/delete/alter fields to result.
#  |
#  |  fetch_content(self, url)
#  |
#  |  geotag_result(self, result, soup)
#  |      Adds (lat, lng) to result.
#  |
#  |  geotag_results(self, results, workers=8)
#  |      Add (lat, lng) to each result. This process is done using N threads,
#  |      where N is the amount of workers defined (default: 8).
#  |
#  |  get_results(self, limit=None, start=0, sort_by=None, geotagged=False, include_details=False)
# ...

# %%
help(CraigslistBase.extra_filters)
# Out:
# Help on dict object:
#
# class dict(object)
#  |  dict() -> new empty dictionary
#  |  dict(mapping) -> new dictionary initialized from a mapping object's
#  |      (key, value) pairs
#  |  dict(iterable) -> new dictionary initialized as if via:
#  |      d = {}
#  |      for k, v in iterable:
#  |          d[k] = v
#  |  dict(**kwargs) -> new dictionary initialized with the name=value pairs
#  |      in the keyword argument list.  For example:  dict(one=1, two=2)
#  |
#  |  Methods defined here:
#  |
#  |  __contains__(self, key, /)
#  |      True if the dictionary has the specified key, else False.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
# ...

# %%
CraigslistBase.extra_filters
# Out:
# {}

# %%
{
'apa':'apartments/housing for rent',
'sub':'sublets and temporary',
'prk':'parking and storage',
'roo':'rooms and shares',
'off':'office and commercial',
'sbw':'sublet/temp wanted',
'hou':'apartments wanted',
'swp':'housing swap',
'reb':'real estate by broker',
'reo':'real estate by owner',
'rew':'real estate wanted',
'sha':'rooms wanted',
'vac':'vacation rentals',
'hhh':'all'
}
